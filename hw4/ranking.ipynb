# %% [markdown]
# #### 資料預處理
# 使用hw1的爬蟲程式後會得到一直到現時刻的ETF資料，每檔ETF為一個csv檔，全部放在datadir資料夾底下。接著把資料處理成3年期間內每隔一週取一筆資料和每隔一月取筆資料的形式，另外，將原本的價格資料轉化為與上期的變動比例，以便後續計算。

# %%
import os, pickle
import pandas as pd
etf_list = os.listdir('datadir/')
years = 3
days_of_week = 5
weeks_of_year = 52
days_of_month = 21
months_of_year = 12
etf_dict = {}
for fname in etf_list:
    etf_name = fname.split('.')[0]
    data = pd.read_csv('datadir/' + fname, parse_dates = True)['Adj Close']
    week_data = []
    for i in range(len(data) - days_of_week * weeks_of_year * years, len(data), days_of_week):
        week_data.append(data[i])
    for i in range(len(week_data) -1, 0, -1):
        week_data[i] = (week_data[i] - week_data[i - 1]) / week_data[i - 1]
    del week_data[0]
    month_data = []
    for i in range(len(data) - days_of_month * months_of_year * years, len(data), days_of_month):
        month_data.append(data[i])
    for i in range(len(month_data) -1, 0, -1):
        month_data[i] = (month_data[i] - month_data[i - 1]) / month_data[i - 1]
    del month_data[0]
    etf_dict[etf_name] = {'week_data': week_data, 'month_data': month_data}
with open('etf_dict.pkl', 'wb') as f:
    pickle.dump(etf_dict, f)

# %%
import os, pickle
with open('etf_dict.pkl', 'rb') as f:
    etf_dict = pickle.load(f)

# %% [markdown]
# #### 三種指標的計算

# %%
def evaluate_A(X, is_month = True):
    X = np.array(X)
    mu, sigma, skew = np.mean(X), np.std(X), scipy.stats.skew(X)
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    SR = (mu - r) / sigma * dt ** 0.5
    b3 = 2
    ASSR = SR * (1 + b3 * skew / 3 * SR) ** 0.5
    return ASSR
def evaluate_B(X, is_month = True):
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    A = np.array(X)
    B = np.array(list(filter(lambda x: x < r, X)))
    omega = (np.mean(A) - r) / ((r * len(B) - np.sum(B)) / len(A))
    return omega
def f(x, g, r):
    return sum([np.exp(-x * (i - r)) for i in g]) - len(g)
def evaluate_C(X, is_month = True, etf = ''):
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    roots = fsolve(f, [15], (X, r))
    if roots[0] > 1e-5:
        root = roots[0]
    else:
        roots = fsolve(f, [-15], (X, r))
        root = roots[0]
    return np.exp(-roots[0])

# %%
import numpy as np
import scipy.stats
from scipy.optimize import root,fsolve
import matplotlib.pyplot as plt
score = {'week': {}, 'month': {}}
rf = 0.0243
etf_list = [etf for etf in etf_dict]
for etf in etf_dict:
    score['week'][etf] = {'A': evaluate_A(etf_dict[etf]['week_data'], False), 'B': evaluate_B(etf_dict[etf]['week_data'], False), 'C': evaluate_C(etf_dict[etf]['week_data'], False, etf)}
    score['month'][etf] = {'A': evaluate_A(etf_dict[etf]['month_data']), 'B': evaluate_B(etf_dict[etf]['month_data']), 'C': evaluate_C(etf_dict[etf]['month_data'])}
score['week']
# Out:
# {'NFRA': {'A': 0.008323470543617147,
#   'B': 0.17338379213769908,
#   'C': 0.0003920036072456576},
#  'DOL': {'A': 0.01148105178809248,
#   'B': 0.25585355215750955,
#   'C': 0.00010218643455262517},
#  'CGW': {'A': 0.016867309735854166,
#   'B': 0.38711041253935236,
#   'C': 7.808057022575456e-07},
#  'SMH': {'A': 0.02522092663946969,
#   'B': 0.6183294300189554,
#   'C': 6.400351108172568e-06},
#  'JXI': {'A': 0.012015579341412157,
#   'B': 0.2589053714202352,
#   'C': 2.2974160473128374e-05},
#  'EFA': {'A': 0.012076702059478563,
#   'B': 0.2699380518040314,
#   'C': 7.407539588619816e-05},
#  'EFV': {'A': 0.011408281725466237,
#   'B': 0.26109316812668365,
#   'C': 0.00020128006958852144},
#  'HEFA': {'A': 0.015624767409516738,
#   'B': 0.3505321304599574,
#   'C': 2.9508361113433935e-06},
#  'GDX': {'A': 0.007765804812899182,
#   'B': 0.15362405254853292,
#   'C': 0.07240156171414239},
#  'VT': {'A': 0.0152557869160234,
#   'B': 0.34394100061780697,
#   'C': 3.6808367645698757e-06},
#  'VEA': {'A': 0.012760753015594647,
#   'B': 0.28476689068485883,
#   'C': 4.6271667319029744e-05},
#  'DWM': {'A': 0.011803323792343454,
#   'B': 0.26383165656646257,
#   'C': 6.358566089588245e-05},
#  'GII': {'A': 0.016126750383618136,
#   'B': 0.36081376380551167,
#   'C': 3.710312614556949e-07},
#  'IDV': {'A': 0.014026459175577117,
#   'B': 0.3156279945683812,
#   'C': 1.1081608192535262e-05},
#  'PID': {'A': 0.015746479939477875,
#   'B': 0.36558180078889563,
#   'C': 9.039533933117238e-06},
#  'IVLU': {'A': 0.011492270078098839,
#   'B': 0.26115701570355127,
#   'C': 0.0002031520150115967},
#  'DWX': {'A': 0.015737395095519816,
#   'B': 0.36807691635973633,
#   'C': 2.665233262616846e-06},
#  'SDIV': {'A': 0.011680068393502054,
#   'B': 0.25274110616277484,
#   'C': 4.835013063474618e-05},
#  'DLS': {'A': 0.013783548347173267,
#   'B': 0.2981519231993954,
#   'C': 1.95532217409959e-05},
#  'VEU': {'A': 0.013992071181840144,
#   'B': 0.3089149011010312,
#   'C': 2.2274455905303388e-05},
#  'EFG': {'A': 0.01208234152045489,
#   'B': 0.25535347641648537,
#   'C': 6.505398865054316e-05},
#  'VXUS': {'A': 0.013208170209319596,
#   'B': 0.28990674334883065,
#   'C': 4.1312634042193e-05},
#  'KXI': {'A': 0.0066440667088116575,
#   'B': 0.13975287120707755,
#   'C': 0.0017806723809546967},
#  'TAN': {'A': 0.004394367856708142,
#   'B': 0.08634313421860584,
#   'C': 0.16549735766751444},
#  'FNDC': {'A': 0.013815849598465942,
#   'B': 0.3036206644854433,
#   'C': 2.314875780359935e-05},
#  'IXJ': {'A': 0.013719933348122918,
#   'B': 0.29023977929054057,
#   'C': 2.8404249782608928e-05},
#  'IQLT': {'A': 0.013586676853220753,
#   'B': 0.3027563550005505,
#   'C': 2.0602708704474948e-05},
#  'SCHF': {'A': 0.013079930143227603,
#   'B': 0.2945423838988082,
#   'C': 3.2694658071164214e-05},
#  'DIM': {'A': 0.012829946555827454,
#   'B': 0.29216741548201725,
#   'C': 4.245531034962659e-05},
#  'WDIV': {'A': 0.015827264453333698,
#   'B': 0.3631448833831175,
#   'C': 6.846369151794244e-07},
#  'FGD': {'A': 0.011888954727477185,
#   'B': 0.2694303619911285,
#   'C': 7.405866643355098e-05},
#  'RXI': {'A': 0.01652237745357933,
#   'B': 0.3740218814944007,
#   'C': 2.8636785269851104e-06},
#  'MXI': {'A': 0.01756613274846948,
#   'B': 0.3944385096935867,
#   'C': 2.0933472098897475e-05},
#  'CWI': {'A': 0.013793213966584526,
#   'B': 0.3017947151119346,
#   'C': 2.9298691327984567e-05},
#  'ACWV': {'A': 0.01964404864479094,
#   'B': 0.48261564030680537,
#   'C': 3.2779247622327845e-10},
#  'CRBN': {'A': 0.018341826351565553,
#   'B': 0.4270905024550674,
#   'C': 2.316259323227787e-07},
#  'SCHC': {'A': 0.012306515848913216,
#   'B': 0.26103287092695243,
#   'C': 9.713973255788354e-05},
#  'GDXJ': {'A': 0.009943641517256406,
#   'B': 0.20804696877983536,
#   'C': 0.06119707925826952},
#  'LIT': {'A': 0.01658171642456769,
#   'B': 0.355207126066331,
#   'C': 0.0004842716785647136},
#  'INTF': {'A': 0.010882819389846,
#   'B': 0.23452583317462,
#   'C': 0.0002540239122898573},
#  'IDOG': {'A': 0.01311838449023972,
#   'B': 0.2929397917861787,
#   'C': 5.109403293362622e-05},
#  'FNDF': {'A': 0.013331358147722207,
#   'B': 0.3075903899780668,
#   'C': 4.355789334486592e-05},
#  'GWX': {'A': 0.010805175547911747,
#   'B': 0.22214517838883752,
#   'C': 0.0003119005765425689},
#  'TLTD': {'A': 0.01243304235076962,
#   'B': 0.27585623517678576,
#   'C': 6.41771271879839e-05},
#  'FDT': {'A': 0.009680083361139229,
#   'B': 0.20114816165525598,
#   'C': 0.001238650134174554},
#  'URTH': {'A': 0.015695938262879194,
#   'B': 0.36196602272741174,
#   'C': 2.1560062912473644e-06},
#  'MOO': {'A': 0.01712486614154456,
#   'B': 0.3950725358973254,
#   'C': 2.7369363161978695e-06},
#  'DBEF': {'A': 0.015853609238019744,
#   'B': 0.3552120939860847,
#   'C': 1.7090885621817477e-06},
#  'ACWX': {'A': 0.013875399875020166,
#   'B': 0.3043686511527734,
#   'C': 2.481956374350078e-05},
#  'HEZU': {'A': 0.014643952852660845,
#   'B': 0.3262052916727099,
#   'C': 2.000368970723006e-05},
#  'IXC': {'A': 0.011631095741283657,
#   'B': 0.24344107117045793,
#   'C': 0.001197516073233065},
#  'EFAV': {'A': 0.011213899161000464,
#   'B': 0.24320259426525898,
#   'C': 9.150776374620026e-06},
#  'PICK': {'A': 0.019837993615339652,
#   'B': 0.4470697409644115,
#   'C': 0.0004170523309380448},
#  'PXF': {'A': 0.013143125296341866,
#   'B': 0.3050963365680684,
#   'C': 6.274914697125523e-05},
#  'URA': {'A': 0.004056342093633794,
#   'B': 0.08033019158145764,
#   'C': 0.25727212756841344},
#  'SPDW': {'A': 0.01097186364933968,
#   'B': 0.2376371081667093,
#   'C': 0.00017615771085882688},
#  'SIL': {'A': 0.007607148493322905,
#   'B': 0.15569752534441608,
#   'C': 0.09999338345880315},
#  'HDEF': {'A': 0.010442955249842446,
#   'B': 0.2502118803396094,
#   'C': 0.0002840907751056103},
#  'ACWI': {'A': 0.019004646760551455,
#   'B': 0.4446928947018116,
#   'C': 1.360662449845995e-07},
#  'IDLV': {'A': 0.01530161695053729,
#   'B': 0.35397859325835307,
#   'C': 2.69388803681134e-07},
#  'IXP': {'A': 0.0016851351237290497,
#   'B': 0.03263382551348244,
#   'C': 0.2441786146673992},
#  'IXG': {'A': 0.012825203671144671,
#   'B': 0.2884847570275421,
#   'C': 0.0002814060671971239},
#  'ROBO': {'A': 0.019717821901960548,
#   'B': 0.45835175887830804,
#   'C': 2.6718006968461846e-05},
#  'GNR': {'A': 0.017813793057538174,
#   'B': 0.4109826633603021,
#   'C': 2.0549286931715634e-05},
#  'EZU': {'A': 0.010418282589803877,
#   'B': 0.2238725033762069,
#   'C': 0.001030757598102631},
#  'GUNR': {'A': 0.018544273497009763,
#   'B': 0.42583650294567266,
#   'C': 6.9856377136974516e-06},
#  'WOOD': {'A': 0.019224222879674832,
#   'B': 0.45620821854204857,
#   'C': 7.445232232548616e-06},
#  'QEFA': {'A': 0.012562707872015915,
#   'B': 0.2746683339290296,
#   'C': 1.2099791311341154e-05},
#  'IEFA': {'A': 0.012733245548841947,
#   'B': 0.2851106078810062,
#   'C': 4.6509308300439924e-05},
#  'IOO': {'A': 0.0196526299780106,
#   'B': 0.4518092092400113,
#   'C': 9.578723838754436e-08},
#  'EWS': {'A': 0.012605620160602815,
#   'B': 0.2636062952713292,
#   'C': 0.0002627589372476299},
#  'PPH': {'A': 0.002748461252283432,
#   'B': 0.051900668500115085,
#   'C': 0.1793201916429821},
#  'PSP': {'A': 0.017007546567216567,
#   'B': 0.38516280166801903,
#   'C': 9.765673488515071e-06},
#  'PDN': {'A': 0.01245984992584748,
#   'B': 0.26382130119699676,
#   'C': 7.168494896129827e-05},
#  'NUGT': {'A': 0.005020386064993992,
#   'B': 0.09765291602412897,
#   'C': 0.5694979776001593},
#  'HFXI': {'A': 0.013232030163003785,
#   'B': 0.2931803297211062,
#   'C': 2.853260884812233e-05},
#  'VSS': {'A': 0.012745630230089237,
#   'B': 0.2688787378915721,
#   'C': 6.959356586520487e-05},
#  'JNUG': {'A': 0.007301187993344872,
#   'B': 0.15102498782464416,
#   'C': 0.5038878601049107},
#  'SCZ': {'A': 0.009745223478045136,
#   'B': 0.20416815753841203,
#   'C': 0.0007732244956915462},
#  'DTH': {'A': 0.011666168471243342,
#   'B': 0.26066735918139244,
#   'C': 0.00010418535149125408},
#  'IQDF': {'A': 0.01158486342054156,
#   'B': 0.257200925734223,
#   'C': 0.0001216713428047593},
#  'IXUS': {'A': 0.014157867783020736,
#   'B': 0.3124308302063374,
#   'C': 1.9631690674321398e-05},
#  'IGF': {'A': 0.015843590698812807,
#   'B': 0.3593234379128149,
#   'C': 3.8488610409245513e-07},
#  'JPGE': {'A': 0.014702923525387131,
#   'B': 0.33369354911517995,
#   'C': 1.8655930661655981e-06},
#  'JPIN': {'A': 0.00756521977391587,
#   'B': 0.15690506800020307,
#   'C': 0.0018526986507532855},
#  'XT': {'A': 0.024748946047741208,
#   'B': 0.6055695559833559,
#   'C': 2.094920928598751e-08},
#  'GSIE': {'A': 0.012696949174918938,
#   'B': 0.2809783424996867,
#   'C': 2.916032454240634e-05},
#  'RODM': {'A': 0.017533135714668944,
#   'B': 0.3947869130753109,
#   'C': 5.768552256095122e-08},
#  'IHDG': {'A': 0.014077457757365942,
#   'B': 0.30490321852232566,
#   'C': 5.866687262595451e-06}}

# %% [markdown]
# 將ETF照指標結果排序，其中A和B指標越大越好，C指標是risk index，越小越好。

# %%
import pandas as pd
ranking = {}
for interval in ['week', 'month']:
    ranking[interval] = {}
    for evl in ['A', 'B', 'C']:
        ranking[interval][evl] = sorted(etf_list, key = lambda x:  score[interval][x][evl], reverse = (evl != 'C'))

# %% [markdown]
# #### 週分析資料

# %%
df = {}
for interval in ['week', 'month']:
    df[interval] = {}
    for evl in ['A', 'B', 'C']:
        df[interval][evl] = pd.DataFrame(ranking[interval][evl], index = list(range(1, len(etf_list) + 1)), columns = ['ETF Symbol'])
        df[interval][evl].index.name = 'Ranking'
        df[interval][evl].columns.name = evl + '指標'
display(df['week']['A'])
display(df['week']['B'])
display(df['week']['C'])
# Out:
# A指標     ETF Symbol
# Ranking
# 1              SMH
# 2               XT
# 3             PICK
# 4             ROBO
# 5              IOO
# 6             ACWV
# 7             WOOD
# 8             ACWI
# 9             GUNR
# 10            CRBN
# 11             GNR
# 12             MXI
# 13            RODM
# 14             MOO
# 15             PSP
# 16             CGW
# 17             LIT
# 18             RXI
# 19             GII
# 20            DBEF
# 21             IGF
# 22            WDIV
# 23             PID
# 24             DWX
# 25            URTH
# 26            HEFA
# 27            IDLV
# 28              VT
# 29            JPGE
# 30            HEZU
# ...            ...
# 60             JXI
# 61             FGD
# 62             DWM
# 63            SDIV
# 64             DTH
# 65             IXC
# 66            IQDF
# 67            IVLU
# 68             DOL
# 69             EFV
# 70            EFAV
# 71            SPDW
# 72            INTF
# 73             GWX
# 74            HDEF
# 75             EZU
# 76            GDXJ
# 77             SCZ
# 78             FDT
# 79            NFRA
# 80             GDX
# 81             SIL
# 82            JPIN
# 83            JNUG
# 84             KXI
# 85            NUGT
# 86             TAN
# 87             URA
# 88             PPH
# 89             IXP
#
# [89 rows x 1 columns]
# B指標     ETF Symbol
# Ranking
# 1              SMH
# 2               XT
# 3             ACWV
# 4             ROBO
# 5             WOOD
# 6              IOO
# 7             PICK
# 8             ACWI
# 9             CRBN
# 10            GUNR
# 11             GNR
# 12             MOO
# 13            RODM
# 14             MXI
# 15             CGW
# 16             PSP
# 17             RXI
# 18             DWX
# 19             PID
# 20            WDIV
# 21            URTH
# 22             GII
# 23             IGF
# 24            DBEF
# 25             LIT
# 26            IDLV
# 27            HEFA
# 28              VT
# 29            JPGE
# 30            HEZU
# ...            ...
# 60            IVLU
# 61             EFV
# 62            SCHC
# 63             DTH
# 64             JXI
# 65            IQDF
# 66             DOL
# 67             EFG
# 68            SDIV
# 69            HDEF
# 70             IXC
# 71            EFAV
# 72            SPDW
# 73            INTF
# 74             EZU
# 75             GWX
# 76            GDXJ
# 77             SCZ
# 78             FDT
# 79            NFRA
# 80            JPIN
# 81             SIL
# 82             GDX
# 83            JNUG
# 84             KXI
# 85            NUGT
# 86             TAN
# 87             URA
# 88             PPH
# 89             IXP
#
# [89 rows x 1 columns]
# C指標     ETF Symbol
# Ranking
# 1             ACWV
# 2               XT
# 3             RODM
# 4              IOO
# 5             ACWI
# 6             CRBN
# 7             IDLV
# 8              GII
# 9              IGF
# 10            WDIV
# 11             CGW
# 12            DBEF
# 13            JPGE
# 14            URTH
# 15             DWX
# 16             MOO
# 17             RXI
# 18            HEFA
# 19              VT
# 20            IHDG
# 21             SMH
# 22            GUNR
# 23            WOOD
# 24             PID
# 25            EFAV
# 26             PSP
# 27             IDV
# 28            QEFA
# 29             DLS
# 30            IXUS
# ...            ...
# 60            SCHC
# 61             DOL
# 62             DTH
# 63            IQDF
# 64            SPDW
# 65             EFV
# 66            IVLU
# 67            INTF
# 68             EWS
# 69             IXG
# 70            HDEF
# 71             GWX
# 72            NFRA
# 73            PICK
# 74             LIT
# 75             SCZ
# 76             EZU
# 77             IXC
# 78             FDT
# 79             KXI
# 80            JPIN
# 81            GDXJ
# 82             GDX
# 83             SIL
# 84             TAN
# 85             PPH
# 86             IXP
# 87             URA
# 88            JNUG
# 89            NUGT
#
# [89 rows x 1 columns]

# %% [markdown]
# #### 月分析資料

# %%
display(df['month']['A'])
display(df['month']['B'])
display(df['month']['C'])
# Out:
# A指標     ETF Symbol
# Ranking
# 1               XT
# 2              SMH
# 3              MOO
# 4              IOO
# 5             ACWI
# 6             CRBN
# 7             ROBO
# 8             ACWV
# 9             WOOD
# 10            GUNR
# 11             CGW
# 12            PICK
# 13             MXI
# 14             RXI
# 15             GNR
# 16             IXJ
# 17            RODM
# 18             PSP
# 19             LIT
# 20            URTH
# 21            WDIV
# 22            JPGE
# 23              VT
# 24             GII
# 25            DBEF
# 26            HEFA
# 27             IGF
# 28             DWX
# 29             PID
# 30            IDLV
# ...            ...
# 60             DOL
# 61            INTF
# 62             DTH
# 63             EFG
# 64            IVLU
# 65             VSS
# 66            SCHC
# 67            SDIV
# 68            EFAV
# 69             EFV
# 70            IQDF
# 71            SPDW
# 72             IXC
# 73             GWX
# 74             FDT
# 75            GDXJ
# 76             EZU
# 77            HDEF
# 78             SCZ
# 79            JPIN
# 80             GDX
# 81            NFRA
# 82             SIL
# 83             PPH
# 84             KXI
# 85            JNUG
# 86             URA
# 87             TAN
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]
# B指標     ETF Symbol
# Ranking
# 1               XT
# 2              SMH
# 3              MOO
# 4              IOO
# 5             ACWI
# 6             ROBO
# 7             CRBN
# 8              CGW
# 9             ACWV
# 10            GUNR
# 11            WOOD
# 12            PICK
# 13             GNR
# 14             MXI
# 15             PSP
# 16             RXI
# 17            RODM
# 18            WDIV
# 19             LIT
# 20            JPGE
# 21             IXJ
# 22            DBEF
# 23            HEFA
# 24            URTH
# 25             GII
# 26             DWX
# 27             IGF
# 28              VT
# 29             PID
# 30            IDLV
# ...            ...
# 60             EWS
# 61            INTF
# 62             EFG
# 63            IVLU
# 64             JXI
# 65            SCHC
# 66            SDIV
# 67             VSS
# 68             IXC
# 69            EFAV
# 70             EFV
# 71            SPDW
# 72             GWX
# 73            IQDF
# 74             EZU
# 75             FDT
# 76            GDXJ
# 77            HDEF
# 78             SCZ
# 79            NFRA
# 80            JPIN
# 81             GDX
# 82             SIL
# 83             KXI
# 84             PPH
# 85            JNUG
# 86             URA
# 87             TAN
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]
# C指標     ETF Symbol
# Ranking
# 1               XT
# 2              MOO
# 3              IOO
# 4             ACWV
# 5             CRBN
# 6             ACWI
# 7             RODM
# 8             WDIV
# 9             URTH
# 10             CGW
# 11             RXI
# 12             GII
# 13            JPGE
# 14            IDLV
# 15             IGF
# 16             IXJ
# 17              VT
# 18             DWX
# 19            GUNR
# 20            HEFA
# 21            DBEF
# 22             IDV
# 23             SMH
# 24             CWI
# 25            IQLT
# 26             VEU
# 27             PID
# 28            IXUS
# 29            ACWX
# 30             MXI
# ...            ...
# 60             JXI
# 61             IXG
# 62            SPDW
# 63            SDIV
# 64             EFV
# 65            IVLU
# 66            SCHC
# 67            IQDF
# 68             VSS
# 69             EWS
# 70             LIT
# 71            PICK
# 72             GWX
# 73             EZU
# 74            HDEF
# 75             FDT
# 76            NFRA
# 77             SCZ
# 78             IXC
# 79            JPIN
# 80             KXI
# 81             PPH
# 82            GDXJ
# 83             GDX
# 84             SIL
# 85             URA
# 86             TAN
# 87            JNUG
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]

# %% [markdown]
# #### 相似度分析
# 此部分的數據會在README.md中用來分析評比結果的相似程度。

# %%
def reversed_pairs(A):
    ret = 0
    for i in range(len(A)):
        for j in range(i + 1, len(A)):
            if A[i] > A[j]:
                ret += 1
    return ret
def similarity(A, B):
    for i in range(len(B)):
        B[i] = A.index(B[i]) + 1
    return reversed_pairs(B) / (len(B) * (len(B) - 1) / 2)

# %%
print(similarity(list(ranking['week']['A']), list(ranking['week']['B'])))
print(similarity(list(ranking['week']['B']), list(ranking['week']['C'])))
print(similarity(list(ranking['week']['A']), list(ranking['week']['C'])))
# Out:
# 0.03268641470888662
# 0.1481103166496425
# 0.14198161389172625

# %%
print(similarity(list(ranking['month']['A']), list(ranking['month']['B'])))
print(similarity(list(ranking['month']['B']), list(ranking['month']['C'])))
print(similarity(list(ranking['month']['A']), list(ranking['month']['C'])))
# Out:
# 0.018896833503575076
# 0.12538304392236976
# 0.1274259448416752

# %%
print(similarity(list(ranking['week']['A']), list(ranking['month']['A'])))
print(similarity(list(ranking['week']['B']), list(ranking['month']['B'])))
print(similarity(list(ranking['week']['C']), list(ranking['month']['C'])))
# Out:
# 0.05669050051072523
# 0.06128702757916241
# 0.1008682328907048
