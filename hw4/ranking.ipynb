# %% [markdown]
# #### 資料預處理
# 使用hw1的爬蟲程式後會得到一直到現時刻的ETF資料，每檔ETF為一個csv檔，全部放在datadir資料夾底下。接著把資料處理成3年期間內每隔一週取一筆資料和每隔一月取筆資料的形式，另外，將原本的價格資料轉化為與上期的變動比例，以便後續計算。

# %%
import os, pickle
import pandas as pd
etf_list = os.listdir('datadir/')
years = 3
days_of_week = 5
weeks_of_year = 52
days_of_month = 21
months_of_year = 12
etf_dict = {}
for fname in etf_list:
    etf_name = fname.split('.')[0]
    data = pd.read_csv('datadir/' + fname, parse_dates = True)['Adj Close']
    week_data = []
    for i in range(len(data) - days_of_week * weeks_of_year * years, len(data), days_of_week):
        week_data.append(data[i])
    for i in range(len(week_data) -1, 0, -1):
        week_data[i] = (week_data[i] - week_data[i - 1]) / week_data[i - 1]
    del week_data[0]
    month_data = []
    for i in range(len(data) - days_of_month * months_of_year * years, len(data), days_of_month):
        month_data.append(data[i])
    for i in range(len(month_data) -1, 0, -1):
        month_data[i] = (month_data[i] - month_data[i - 1]) / month_data[i - 1]
    del month_data[0]
    etf_dict[etf_name] = {'week_data': week_data, 'month_data': month_data}
with open('etf_dict.pkl', 'wb') as f:
    pickle.dump(etf_dict, f)

# %%
import os, pickle
with open('etf_dict.pkl', 'rb') as f:
    etf_dict = pickle.load(f)

# %% [markdown]
# #### 三種指標的計算

# %%
def evaluate_A(X, is_month = True):
    X = np.array(X)
    mu, sigma, skew = np.mean(X), np.std(X), scipy.stats.skew(X)
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    SR = (mu - r) / sigma * dt ** 0.5
    b3 = 2
    ASSR = SR * (1 + b3 * skew / 3 * SR) ** 0.5
    return ASSR
def evaluate_B(X, is_month = True):
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    A = np.array(X)
    B = np.array(list(filter(lambda x: x < r, X)))
    omega = (np.mean(A) - r) / (r - np.mean(B))
    return omega
def f(x, g, r):
    return sum([np.exp(-x * (i - r)) for i in g]) - len(g)
def evaluate_C(X, is_month = True):
    dt = 1 / 12 if is_month else 1 / 52
    r = rf * dt
    roots = fsolve(f, [20], (X, r))
    return np.exp(-roots[0])

# %%
import numpy as np
import scipy.stats
from scipy.optimize import root,fsolve
import matplotlib.pyplot as plt
score = {'week': {}, 'month': {}}
rf = 0.0243
etf_list = [etf for etf in etf_dict]
for etf in etf_dict:
    score['week'][etf] = {'A': evaluate_A(etf_dict[etf]['week_data'], False), 'B': evaluate_B(etf_dict[etf]['week_data'], False), 'C': evaluate_C(etf_dict[etf]['week_data'], False)}
    score['month'][etf] = {'A': evaluate_A(etf_dict[etf]['month_data']), 'B': evaluate_B(etf_dict[etf]['month_data']), 'C': evaluate_C(etf_dict[etf]['month_data'])}
score['week']
# Out:
# {'NFRA': {'A': 0.008323470543617147,
#   'B': 0.08053956796073765,
#   'C': 0.0003920036072460333},
#  'DOL': {'A': 0.01148105178809248,
#   'B': 0.11554676549048819,
#   'C': 0.0001021864345525629},
#  'CGW': {'A': 0.016867309735854166,
#   'B': 0.16982908421081266,
#   'C': 7.808057022576732e-07},
#  'SMH': {'A': 0.02522092663946969,
#   'B': 0.2353641056201185,
#   'C': 6.400351108173569e-06},
#  'JXI': {'A': 0.012015579341412157,
#   'B': 0.11191393474294037,
#   'C': 2.2974160473115967e-05},
#  'EFA': {'A': 0.012076702059478563,
#   'B': 0.1166828998120652,
#   'C': 7.407539588620512e-05},
#  'EFV': {'A': 0.011408281725466237,
#   'B': 0.11454409956525474,
#   'C': 0.000201280069588431},
#  'HEFA': {'A': 0.015624767409516738,
#   'B': 0.13342835933637087,
#   'C': 2.9508361113426807e-06},
#  'GDX': {'A': 0.007765804812899182,
#   'B': 0.07730758773410043,
#   'C': 0.07240156171414872},
#  'VT': {'A': 0.0152557869160234,
#   'B': 0.139795374444657,
#   'C': 3.6808367645693132e-06},
#  'VEA': {'A': 0.012760753015594647,
#   'B': 0.1249299907520671,
#   'C': 4.6271667319042565e-05},
#  'DWM': {'A': 0.011803323792343454,
#   'B': 0.11574550094528678,
#   'C': 6.358566089589149e-05},
#  'GII': {'A': 0.016126750383618136,
#   'B': 0.16294815139603755,
#   'C': 3.710312614556106e-07},
#  'IDV': {'A': 0.014026459175577117,
#   'B': 0.14457798460874235,
#   'C': 1.108160819253416e-05},
#  'PID': {'A': 0.015746479939477875,
#   'B': 0.1698186429470999,
#   'C': 9.03953393312546e-06},
#  'IVLU': {'A': 0.011492270078098839,
#   'B': 0.10783257422598247,
#   'C': 0.00020315201501166708},
#  'DWX': {'A': 0.015737395095519816,
#   'B': 0.1686029745905889,
#   'C': 2.6652332626165427e-06},
#  'SDIV': {'A': 0.011680068393502054,
#   'B': 0.1059882058101959,
#   'C': 4.8350130634739574e-05},
#  'DLS': {'A': 0.013783548347173267,
#   'B': 0.11541364769008852,
#   'C': 1.955322174099642e-05},
#  'VEU': {'A': 0.013992071181840144,
#   'B': 0.12356596044041247,
#   'C': 2.2274455905308494e-05},
#  'EFG': {'A': 0.01208234152045489,
#   'B': 0.11202604126658712,
#   'C': 6.505398865053658e-05},
#  'VXUS': {'A': 0.013208170209319596,
#   'B': 0.11783306342565375,
#   'C': 4.131263404217546e-05},
#  'KXI': {'A': 0.0066440667088116575,
#   'B': 0.060409305618543206,
#   'C': 0.001780672380951853},
#  'TAN': {'A': 0.004394367856708142,
#   'B': 0.040107778475739486,
#   'C': 0.16549735766762538},
#  'FNDC': {'A': 0.013815849598465942,
#   'B': 0.1214482657941773,
#   'C': 2.31487578035998e-05},
#  'IXJ': {'A': 0.013719933348122918,
#   'B': 0.13294854406211856,
#   'C': 2.8404249782612208e-05},
#  'IQLT': {'A': 0.013586676853220753,
#   'B': 0.12696234241958568,
#   'C': 2.0602708704472386e-05},
#  'SCHF': {'A': 0.013079930143227603,
#   'B': 0.11781695355952328,
#   'C': 3.269465807117688e-05},
#  'DIM': {'A': 0.012829946555827454,
#   'B': 0.10932716192230325,
#   'C': 4.245531034962493e-05},
#  'WDIV': {'A': 0.015827264453333698,
#   'B': 0.15228656399937188,
#   'C': 6.846369151794171e-07},
#  'FGD': {'A': 0.011888954727477185,
#   'B': 0.11993996759605076,
#   'C': 7.405866643358334e-05},
#  'RXI': {'A': 0.01652237745357933,
#   'B': 0.15684788578797448,
#   'C': 2.8636785269858024e-06},
#  'MXI': {'A': 0.01756613274846948,
#   'B': 0.16795446219210786,
#   'C': 2.0933472098896025e-05},
#  'CWI': {'A': 0.013793213966584526,
#   'B': 0.11877082336663232,
#   'C': 2.929869132797551e-05},
#  'ACWV': {'A': 0.01964404864479094,
#   'B': 0.17436436036891031,
#   'C': 3.277924762233344e-10},
#  'CRBN': {'A': 0.018341826351565553,
#   'B': 0.16256993319257404,
#   'C': 2.316259323228684e-07},
#  'SCHC': {'A': 0.012306515848913216,
#   'B': 0.11114948052373456,
#   'C': 9.713973255789287e-05},
#  'GDXJ': {'A': 0.009943641517256406,
#   'B': 0.1046946036440462,
#   'C': 0.06119707925827014},
#  'LIT': {'A': 0.01658171642456769,
#   'B': 0.15812446257146345,
#   'C': 0.00048427167856470756},
#  'INTF': {'A': 0.010882819389846,
#   'B': 0.09229726337839883,
#   'C': 0.000254023912289948},
#  'IDOG': {'A': 0.01311838449023972,
#   'B': 0.12284571913613945,
#   'C': 5.10940329336245e-05},
#  'FNDF': {'A': 0.013331358147722207,
#   'B': 0.13494288076457123,
#   'C': 4.355789334487056e-05},
#  'GWX': {'A': 0.010805175547911747,
#   'B': 0.10032362894979759,
#   'C': 0.00031190057654269243},
#  'TLTD': {'A': 0.01243304235076962,
#   'B': 0.11390192936331799,
#   'C': 6.41771271879929e-05},
#  'FDT': {'A': 0.009680083361139229,
#   'B': 0.0856501849628832,
#   'C': 0.0012386501341745892},
#  'URTH': {'A': 0.015695938262879194,
#   'B': 0.1401158797654497,
#   'C': 2.156006291247617e-06},
#  'MOO': {'A': 0.01712486614154456,
#   'B': 0.1707732897104568,
#   'C': 2.736936316197753e-06},
#  'DBEF': {'A': 0.015853609238019744,
#   'B': 0.13520976480760644,
#   'C': 1.7090885621817357e-06},
#  'ACWX': {'A': 0.013875399875020166,
#   'B': 0.1256747978953387,
#   'C': 2.481956374350241e-05},
#  'HEZU': {'A': 0.014643952852660845,
#   'B': 0.14100486801336493,
#   'C': 2.0003689707237027e-05},
#  'IXC': {'A': 0.011631095741283657,
#   'B': 0.10208819113599849,
#   'C': 0.0011975160732334191},
#  'EFAV': {'A': 0.011213899161000464,
#   'B': 0.10512628268240226,
#   'C': 9.150776374627797e-06},
#  'PICK': {'A': 0.019837993615339652,
#   'B': 0.21632406820858616,
#   'C': 0.0004170523309380685},
#  'PXF': {'A': 0.013143125296341866,
#   'B': 0.1338487153976042,
#   'C': 6.274914697125646e-05},
#  'URA': {'A': 0.004056342093633794,
#   'B': 0.04301552194361925,
#   'C': 0.2572721275684692},
#  'SPDW': {'A': 0.01097186364933968,
#   'B': 0.10272055643335176,
#   'C': 0.00017615771085875305},
#  'SIL': {'A': 0.007607148493322905,
#   'B': 0.0763420124269395,
#   'C': 0.09999338345884876},
#  'HDEF': {'A': 0.010442955249842446,
#   'B': 0.12752734546341385,
#   'C': 0.00028409077510554217},
#  'ACWI': {'A': 0.019004646760551455,
#   'B': 0.1807461442981557,
#   'C': 1.3606624498458282e-07},
#  'IDLV': {'A': 0.01530161695053729,
#   'B': 0.14844263588253517,
#   'C': 2.693888036809842e-07},
#  'IXP': {'A': 0.0016851351237290497,
#   'B': 0.017264346400681033,
#   'C': 0.24417861466717858},
#  'IXG': {'A': 0.012825203671144671,
#   'B': 0.11911628677266256,
#   'C': 0.00028140606719698544},
#  'ROBO': {'A': 0.019717821901960548,
#   'B': 0.18629781167311874,
#   'C': 2.6718006968462985e-05},
#  'GNR': {'A': 0.017813793057538174,
#   'B': 0.18295357272168286,
#   'C': 2.0549286931715342e-05},
#  'EZU': {'A': 0.010418282589803877,
#   'B': 0.09965937247069853,
#   'C': 0.0010307575981022556},
#  'GUNR': {'A': 0.018544273497009763,
#   'B': 0.18132393028654445,
#   'C': 6.985637713696136e-06},
#  'WOOD': {'A': 0.019224222879674832,
#   'B': 0.17659672975821233,
#   'C': 7.44523223254851e-06},
#  'QEFA': {'A': 0.012562707872015915,
#   'B': 0.11341144110617996,
#   'C': 1.2099791311344184e-05},
#  'IEFA': {'A': 0.012733245548841947,
#   'B': 0.11772308970570576,
#   'C': 4.6509308300449506e-05},
#  'IOO': {'A': 0.0196526299780106,
#   'B': 0.18363858182013362,
#   'C': 9.578723838754709e-08},
#  'EWS': {'A': 0.012605620160602815,
#   'B': 0.12415006164391633,
#   'C': 0.00026275893724758557},
#  'PPH': {'A': 0.002748461252283432,
#   'B': 0.02310416855811575,
#   'C': 0.17932019164324253},
#  'PSP': {'A': 0.017007546567216567,
#   'B': 0.15406512066720757,
#   'C': 9.765673488518072e-06},
#  'PDN': {'A': 0.01245984992584748,
#   'B': 0.1157409579444889,
#   'C': 7.168494896131494e-05},
#  'NUGT': {'A': 0.005020386064993992,
#   'B': 0.04914146741859394,
#   'C': 0.5694979776000608},
#  'HFXI': {'A': 0.013232030163003785,
#   'B': 0.12483807588124522,
#   'C': 2.853260884812056e-05},
#  'VSS': {'A': 0.012745630230089237,
#   'B': 0.11795970436533484,
#   'C': 6.959356586516729e-05},
#  'JNUG': {'A': 0.007301187993344872,
#   'B': 0.07989709033303755,
#   'C': 0.5038878601048803},
#  'SCZ': {'A': 0.009745223478045136,
#   'B': 0.08430169085457012,
#   'C': 0.0007732244956912571},
#  'DTH': {'A': 0.011666168471243342,
#   'B': 0.11940246775405719,
#   'C': 0.0001041853514913046},
#  'IQDF': {'A': 0.01158486342054156,
#   'B': 0.11615525678319749,
#   'C': 0.00012167134280475109},
#  'IXUS': {'A': 0.014157867783020736,
#   'B': 0.12698801485805972,
#   'C': 1.963169067432213e-05},
#  'IGF': {'A': 0.015843590698812807,
#   'B': 0.1483658066220655,
#   'C': 3.8488610409262676e-07},
#  'JPGE': {'A': 0.014702923525387131,
#   'B': 0.14208886607485083,
#   'C': 1.8655930661661417e-06},
#  'JPIN': {'A': 0.00756521977391587,
#   'B': 0.07086035329041429,
#   'C': 0.0018526986507532493},
#  'XT': {'A': 0.024748946047741208,
#   'B': 0.2461347227545253,
#   'C': 2.0949209285985426e-08},
#  'GSIE': {'A': 0.012696949174918938,
#   'B': 0.1178296274998686,
#   'C': 2.9160324542431827e-05},
#  'RODM': {'A': 0.017533135714668944,
#   'B': 0.16810281459980977,
#   'C': 5.7685522560928264e-08},
#  'IHDG': {'A': 0.014077457757365942,
#   'B': 0.1258955224866377,
#   'C': 5.866687262593377e-06}}

# %% [markdown]
# 將ETF照指標結果排序，其中A和B指標越大越好，C指標是risk index，越小越好。

# %%
import pandas as pd
ranking = {}
for interval in ['week', 'month']:
    ranking[interval] = {}
    for evl in ['A', 'B', 'C']:
        ranking[interval][evl] = sorted(etf_list, key = lambda x:  score[interval][x][evl], reverse = (evl != 'C'))

# %% [markdown]
# #### 週分析資料

# %%
df = {}
for interval in ['week', 'month']:
    df[interval] = {}
    for evl in ['A', 'B', 'C']:
        df[interval][evl] = pd.DataFrame(ranking[interval][evl], index = list(range(1, len(etf_list) + 1)), columns = ['ETF Symbol'])
        df[interval][evl].index.name = 'Ranking'
        df[interval][evl].columns.name = evl + '指標'
display(df['week']['A'])
display(df['week']['B'])
display(df['week']['C'])
# Out:
# A指標     ETF Symbol
# Ranking
# 1              SMH
# 2               XT
# 3             PICK
# 4             ROBO
# 5              IOO
# 6             ACWV
# 7             WOOD
# 8             ACWI
# 9             GUNR
# 10            CRBN
# 11             GNR
# 12             MXI
# 13            RODM
# 14             MOO
# 15             PSP
# 16             CGW
# 17             LIT
# 18             RXI
# 19             GII
# 20            DBEF
# 21             IGF
# 22            WDIV
# 23             PID
# 24             DWX
# 25            URTH
# 26            HEFA
# 27            IDLV
# 28              VT
# 29            JPGE
# 30            HEZU
# ...            ...
# 60             JXI
# 61             FGD
# 62             DWM
# 63            SDIV
# 64             DTH
# 65             IXC
# 66            IQDF
# 67            IVLU
# 68             DOL
# 69             EFV
# 70            EFAV
# 71            SPDW
# 72            INTF
# 73             GWX
# 74            HDEF
# 75             EZU
# 76            GDXJ
# 77             SCZ
# 78             FDT
# 79            NFRA
# 80             GDX
# 81             SIL
# 82            JPIN
# 83            JNUG
# 84             KXI
# 85            NUGT
# 86             TAN
# 87             URA
# 88             PPH
# 89             IXP
#
# [89 rows x 1 columns]
# B指標     ETF Symbol
# Ranking
# 1               XT
# 2              SMH
# 3             PICK
# 4             ROBO
# 5              IOO
# 6              GNR
# 7             GUNR
# 8             ACWI
# 9             WOOD
# 10            ACWV
# 11             MOO
# 12             CGW
# 13             PID
# 14             DWX
# 15            RODM
# 16             MXI
# 17             GII
# 18            CRBN
# 19             LIT
# 20             RXI
# 21             PSP
# 22            WDIV
# 23            IDLV
# 24             IGF
# 25             IDV
# 26            JPGE
# 27            HEZU
# 28            URTH
# 29              VT
# 30            DBEF
# ...            ...
# 60             DLS
# 61             EFV
# 62            TLTD
# 63            QEFA
# 64             EFG
# 65             JXI
# 66            SCHC
# 67             DIM
# 68            IVLU
# 69            SDIV
# 70            EFAV
# 71            GDXJ
# 72            SPDW
# 73             IXC
# 74             GWX
# 75             EZU
# 76            INTF
# 77             FDT
# 78             SCZ
# 79            NFRA
# 80            JNUG
# 81             GDX
# 82             SIL
# 83            JPIN
# 84             KXI
# 85            NUGT
# 86             URA
# 87             TAN
# 88             PPH
# 89             IXP
#
# [89 rows x 1 columns]
# C指標     ETF Symbol
# Ranking
# 1             ACWV
# 2               XT
# 3             RODM
# 4              IOO
# 5             ACWI
# 6             CRBN
# 7             IDLV
# 8              GII
# 9              IGF
# 10            WDIV
# 11             CGW
# 12            DBEF
# 13            JPGE
# 14            URTH
# 15             DWX
# 16             MOO
# 17             RXI
# 18            HEFA
# 19              VT
# 20            IHDG
# 21             SMH
# 22            GUNR
# 23            WOOD
# 24             PID
# 25            EFAV
# 26             PSP
# 27             IDV
# 28            QEFA
# 29             DLS
# 30            IXUS
# ...            ...
# 60            SCHC
# 61             DOL
# 62             DTH
# 63            IQDF
# 64            SPDW
# 65             EFV
# 66            IVLU
# 67            INTF
# 68             EWS
# 69             IXG
# 70            HDEF
# 71             GWX
# 72            NFRA
# 73            PICK
# 74             LIT
# 75             SCZ
# 76             EZU
# 77             IXC
# 78             FDT
# 79             KXI
# 80            JPIN
# 81            GDXJ
# 82             GDX
# 83             SIL
# 84             TAN
# 85             PPH
# 86             IXP
# 87             URA
# 88            JNUG
# 89            NUGT
#
# [89 rows x 1 columns]

# %% [markdown]
# #### 月分析資料

# %%
display(df['month']['A'])
display(df['month']['B'])
display(df['month']['C'])
# Out:
# A指標     ETF Symbol
# Ranking
# 1               XT
# 2              SMH
# 3              MOO
# 4              IOO
# 5             ACWI
# 6             CRBN
# 7             ROBO
# 8             ACWV
# 9             WOOD
# 10            GUNR
# 11             CGW
# 12            PICK
# 13             MXI
# 14             RXI
# 15             GNR
# 16             IXJ
# 17            RODM
# 18             PSP
# 19             LIT
# 20            URTH
# 21            WDIV
# 22            JPGE
# 23              VT
# 24             GII
# 25            DBEF
# 26            HEFA
# 27             IGF
# 28             DWX
# 29             PID
# 30            IDLV
# ...            ...
# 60             DOL
# 61            INTF
# 62             DTH
# 63             EFG
# 64            IVLU
# 65             VSS
# 66            SCHC
# 67            SDIV
# 68            EFAV
# 69             EFV
# 70            IQDF
# 71            SPDW
# 72             IXC
# 73             GWX
# 74             FDT
# 75            GDXJ
# 76             EZU
# 77            HDEF
# 78             SCZ
# 79            JPIN
# 80             GDX
# 81            NFRA
# 82             SIL
# 83             PPH
# 84             KXI
# 85            JNUG
# 86             URA
# 87             TAN
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]
# B指標     ETF Symbol
# Ranking
# 1               XT
# 2              SMH
# 3             PICK
# 4              MOO
# 5             GUNR
# 6             ROBO
# 7             CRBN
# 8             ACWI
# 9              GNR
# 10             CGW
# 11             PSP
# 12            RODM
# 13             MXI
# 14            DBEF
# 15            HEFA
# 16            ACWV
# 17             RXI
# 18             IOO
# 19             PID
# 20            WDIV
# 21             LIT
# 22            WOOD
# 23            JPGE
# 24             GII
# 25             VEU
# 26            IXUS
# 27             DWX
# 28             IGF
# 29            ACWX
# 30            VXUS
# ...            ...
# 60             DWM
# 61             DOL
# 62             PXF
# 63            IQDF
# 64            TLTD
# 65             JXI
# 66            SDIV
# 67             VSS
# 68            INTF
# 69            IVLU
# 70             GWX
# 71            GDXJ
# 72            SCHC
# 73             EFV
# 74            SPDW
# 75             EZU
# 76             FDT
# 77             SCZ
# 78            HDEF
# 79             SIL
# 80             GDX
# 81            NFRA
# 82            JPIN
# 83            JNUG
# 84             URA
# 85             KXI
# 86             PPH
# 87             TAN
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]
# C指標     ETF Symbol
# Ranking
# 1               XT
# 2              MOO
# 3              IOO
# 4             ACWV
# 5             CRBN
# 6             ACWI
# 7             RODM
# 8             WDIV
# 9             URTH
# 10             CGW
# 11             RXI
# 12             GII
# 13            JPGE
# 14            IDLV
# 15             IGF
# 16             IXJ
# 17              VT
# 18             DWX
# 19            GUNR
# 20            HEFA
# 21            DBEF
# 22             IDV
# 23             SMH
# 24             CWI
# 25            IQLT
# 26             VEU
# 27             PID
# 28            IXUS
# 29            ACWX
# 30             MXI
# ...            ...
# 60             JXI
# 61             IXG
# 62            SPDW
# 63            SDIV
# 64             EFV
# 65            IVLU
# 66            SCHC
# 67            IQDF
# 68             VSS
# 69             EWS
# 70             LIT
# 71            PICK
# 72             GWX
# 73             EZU
# 74            HDEF
# 75             FDT
# 76            NFRA
# 77             SCZ
# 78             IXC
# 79            JPIN
# 80             KXI
# 81             PPH
# 82            GDXJ
# 83             GDX
# 84             SIL
# 85             URA
# 86             TAN
# 87            JNUG
# 88            NUGT
# 89             IXP
#
# [89 rows x 1 columns]

# %% [markdown]
# #### 相似度分析
# 此部分的數據會在README.md中用來分析評比結果的相似程度。

# %%
def reversed_pairs(A):
    ret = 0
    for i in range(len(A)):
        for j in range(i + 1, len(A)):
            if A[i] > A[j]:
                ret += 1
    return ret
def similarity(A, B):
    for i in range(len(B)):
        B[i] = A.index(B[i]) + 1
    return reversed_pairs(B) / (len(B) * (len(B) - 1) / 2)

# %%
print(similarity(list(ranking['week']['A']), list(ranking['week']['B'])))
print(similarity(list(ranking['week']['B']), list(ranking['week']['C'])))
print(similarity(list(ranking['week']['A']), list(ranking['week']['C'])))
# Out:
# 0.07711950970377937
# 0.18590398365679264
# 0.14198161389172625

# %%
print(similarity(list(ranking['month']['A']), list(ranking['month']['B'])))
print(similarity(list(ranking['month']['B']), list(ranking['month']['C'])))
print(similarity(list(ranking['month']['A']), list(ranking['month']['C'])))
# Out:
# 0.08273748723186926
# 0.17083758937691523
# 0.1274259448416752

# %%
print(similarity(list(ranking['week']['A']), list(ranking['month']['A'])))
print(similarity(list(ranking['week']['B']), list(ranking['month']['B'])))
print(similarity(list(ranking['week']['C']), list(ranking['month']['C'])))
# Out:
# 0.05669050051072523
# 0.11899897854954035
# 0.1008682328907048
